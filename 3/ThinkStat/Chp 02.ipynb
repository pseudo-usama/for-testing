# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exercise 2.2

# %%
df = pd.read_csv('pregnancies.csv')
df
# Out:
#        Unnamed: 0  caseid  nbrnaliv  babysex  birthwgt_lb  birthwgt_oz  \
# 0               0       1       1.0      1.0          8.0         13.0
# 1               1       1       1.0      2.0          7.0         14.0
# 2               2       2       3.0      1.0          9.0          2.0
# 3               3       2       1.0      2.0          7.0          0.0
# 4               4       2       1.0      2.0          6.0          3.0
# ...           ...     ...       ...      ...          ...          ...
# 13588       13588   12571       1.0      1.0          6.0          3.0
# 13589       13589   12571       NaN      NaN          NaN          NaN
# 13590       13590   12571       NaN      NaN          NaN          NaN
# 13591       13591   12571       1.0      1.0          7.0          8.0
# 13592       13592   12571       1.0      1.0          7.0          8.0
#
#        prglength  outcome  birthord  agepreg      finalwgt
# ...
